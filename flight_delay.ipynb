# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('flight.csv')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10524\2472113566.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('flight.csv')

# %%
df1 = df.sample(n=100000)
df1
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 4971115  2015     11    7            6      EV           4197      N12160
# 1471676  2015      4    5            7      DL           1990      N891AT
# 318454   2015      1   21            3      MQ           3471      N514MQ
# 564428   2015      2    7            6      EV           6072      N16918
# 2375725  2015      5   31            7      DL           1086      N922DL
# ...       ...    ...  ...          ...     ...            ...         ...
# 501163   2015      2    3            2      DL            945      N588NW
# 5636536  2015     12   20            7      OO           5661      N125SY
# 3719447  2015      8   19            3      NK            906      N613NK
# 4927718  2015     11    4            3      OO           7426      N935SW
# 2676797  2015      6   18            4      US           1849      N801AW
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
df1.head()
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 4971115  2015     11    7            6      EV           4197      N12160
# 1471676  2015      4    5            7      DL           1990      N891AT
# 318454   2015      1   21            3      MQ           3471      N514MQ
# 564428   2015      2    7            6      EV           6072      N16918
# 2375725  2015      5   31            7      DL           1086      N922DL
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 4971115            SHV                 IAH                  702  ...
# 1471676            ATL                 SAV                  957  ...
# 318454             RDU                 LGA                 1930  ...
# 564428             CVG                 ORD                  820  ...
# 2375725            LGA                 ATL                 1200  ...
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# ...

# %%
df1.shape
# Out:
# (100000, 31)

# %%
df1.isnull().sum()
# Out:
# YEAR                       0
# MONTH                      0
# DAY                        0
# DAY_OF_WEEK                0
# AIRLINE                    0
# FLIGHT_NUMBER              0
# TAIL_NUMBER              263
# ORIGIN_AIRPORT             0
# DESTINATION_AIRPORT        0
# SCHEDULED_DEPARTURE        0
# DEPARTURE_TIME          1511
# DEPARTURE_DELAY         1511
# TAXI_OUT                1564
# WHEELS_OFF              1564
# SCHEDULED_TIME             1
# ELAPSED_TIME            1857
# AIR_TIME                1857
# DISTANCE                   0
# WHEELS_ON               1635
# TAXI_IN                 1635
# SCHEDULED_ARRIVAL          0
# ARRIVAL_TIME            1635
# ARRIVAL_DELAY           1857
# DIVERTED                   0
# CANCELLED                  0
# CANCELLATION_REASON    98421
# AIR_SYSTEM_DELAY       81693
# SECURITY_DELAY         81693
# AIRLINE_DELAY          81693
# LATE_AIRCRAFT_DELAY    81693
# WEATHER_DELAY          81693
# dtype: int64

# %%
df1['CANCELLATION_REASON'].unique()
# Out:
# array([nan, 'B', 'A', 'C'], dtype=object)

# %% [markdown]
# #### Reason for Cancellation of flight: A - Airline/Carrier; B - Weather; C - National Air System; D - Security

# %%
sns.countplot(x='CANCELLATION_REASON',data=df1)
# Out:
# <AxesSubplot:xlabel='CANCELLATION_REASON', ylabel='count'>

# %% [markdown]
# ##### we can see that the majority of flight got cancelled was due to weather

# %%
sns.countplot(x="MONTH",hue="CANCELLATION_REASON",data=df1)
# Out:
# <AxesSubplot:xlabel='MONTH', ylabel='count'>

# %% [markdown]
# #### out of all months,Feb was the month in which the most of the flight got cancelled due to weather.

# %%
plt.figure(figsize=(10, 10))
axis = sns.countplot(x=df1['ORIGIN_AIRPORT'], data =df1, order=df1['ORIGIN_AIRPORT'].value_counts().iloc[:20].index)
axis.set_xticklabels(axis.get_xticklabels(), rotation=90, ha="right")
plt.tight_layout()
plt.show()

# %%
axis = plt.subplots(figsize=(10,14))
Name = df1["AIRLINE"].unique()
size = df1["AIRLINE"].value_counts()
plt.pie(size,labels=Name,autopct='%5.0f%%')
plt.show()

# %%
axis = plt.subplots(figsize=(20,14))
sns.heatmap(df1.corr(),annot = True)
plt.show()

# %%
df1.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#       dtype='object')

# %%
df1.drop(['YEAR',  'FLIGHT_NUMBER','TAIL_NUMBER', 'DEPARTURE_TIME',  'TAXI_OUT','WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME',
 'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
 'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY','LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],axis=1,inplace= True)

# %%
df1.columns
# Out:
# Index(['MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'ORIGIN_AIRPORT',
#        'DESTINATION_AIRPORT', 'SCHEDULED_DEPARTURE', 'DEPARTURE_DELAY',
#        'DISTANCE', 'ARRIVAL_DELAY'],
#       dtype='object')

# %%
df1.head()
# Out:
#          MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 4971115     11    7            6      EV            SHV                 IAH
# 1471676      4    5            7      DL            ATL                 SAV
# 318454       1   21            3      MQ            RDU                 LGA
# 564428       2    7            6      EV            CVG                 ORD
# 2375725      5   31            7      DL            LGA                 ATL
#
#          SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  ARRIVAL_DELAY
# 4971115                  702             -8.0       192            5.0
# 1471676                  957             45.0       214           34.0
# 318454                  1930            -13.0       431          -19.0
# 564428                   820             -2.0       265            2.0
# 2375725                 1200             -5.0       762          -38.0

# %%
airport = pd.read_csv('airports.csv')
airport
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# ...

# %%
df1.loc[~df1.ORIGIN_AIRPORT.isin(airport.IATA_CODE.values),'ORIGIN_AIRPORT']='OTHER'
df1.loc[~df1.DESTINATION_AIRPORT.isin(airport.IATA_CODE.values),'DESTINATION_AIRPORT']='OTHER'
df1
# Out:
#          MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 4971115     11    7            6      EV            SHV                 IAH
# 1471676      4    5            7      DL            ATL                 SAV
# 318454       1   21            3      MQ            RDU                 LGA
# 564428       2    7            6      EV            CVG                 ORD
# 2375725      5   31            7      DL            LGA                 ATL
# ...        ...  ...          ...     ...            ...                 ...
# 501163       2    3            2      DL            DTW                 MSP
# 5636536     12   20            7      OO            SLC                 DEN
# 3719447      8   19            3      NK            OAK                 IAH
# 4927718     11    4            3      OO            INL                 MSP
# 2676797      6   18            4      US            BDL                 CLT
#
# ...

# %%
df1=df1.dropna()
df1
# Out:
#          MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 4971115     11    7            6      EV            SHV                 IAH
# 1471676      4    5            7      DL            ATL                 SAV
# 318454       1   21            3      MQ            RDU                 LGA
# 564428       2    7            6      EV            CVG                 ORD
# 2375725      5   31            7      DL            LGA                 ATL
# ...        ...  ...          ...     ...            ...                 ...
# 501163       2    3            2      DL            DTW                 MSP
# 5636536     12   20            7      OO            SLC                 DEN
# 3719447      8   19            3      NK            OAK                 IAH
# 4927718     11    4            3      OO            INL                 MSP
# 2676797      6   18            4      US            BDL                 CLT
#
# ...

# %%
data=pd.DataFrame(df1)
data['DAY_OF_WEEK']= data['DAY_OF_WEEK'].apply(str)
data["DAY_OF_WEEK"].replace({"1":"SUNDAY", "2": "MONDAY", "3": "TUESDAY", "4":"WEDNESDAY", "5":"THURSDAY", "6":"FRIDAY", "7":"SATURDAY"},inplace=True)
df1
# Out:
#          MONTH  DAY DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 4971115     11    7      FRIDAY      EV            SHV                 IAH
# 1471676      4    5    SATURDAY      DL            ATL                 SAV
# 318454       1   21     TUESDAY      MQ            RDU                 LGA
# 564428       2    7      FRIDAY      EV            CVG                 ORD
# 2375725      5   31    SATURDAY      DL            LGA                 ATL
# ...        ...  ...         ...     ...            ...                 ...
# 501163       2    3      MONDAY      DL            DTW                 MSP
# 5636536     12   20    SATURDAY      OO            SLC                 DEN
# 3719447      8   19     TUESDAY      NK            OAK                 IAH
# 4927718     11    4     TUESDAY      OO            INL                 MSP
# 2676797      6   18   WEDNESDAY      US            BDL                 CLT
#
# ...

# %%
dums = ['AIRLINE','ORIGIN_AIRPORT','DESTINATION_AIRPORT','DAY_OF_WEEK']
df_cat=pd.get_dummies(data[dums],drop_first=True)
df_cat
# Out:
#          AIRLINE_AS  AIRLINE_B6  AIRLINE_DL  AIRLINE_EV  AIRLINE_F9  \
# 4971115           0           0           0           1           0
# 1471676           0           0           1           0           0
# 318454            0           0           0           0           0
# 564428            0           0           0           1           0
# 2375725           0           0           1           0           0
# ...             ...         ...         ...         ...         ...
# 501163            0           0           1           0           0
# 5636536           0           0           0           0           0
# 3719447           0           0           0           0           0
# 4927718           0           0           0           0           0
# 2676797           0           0           0           0           0
#
#          AIRLINE_HA  AIRLINE_MQ  AIRLINE_NK  AIRLINE_OO  AIRLINE_UA  ...  \
# 4971115           0           0           0           0           0  ...
# ...

# %%
var_to_remove=["DAY_OF_WEEK","AIRLINE","ORIGIN_AIRPORT","DESTINATION_AIRPORT"]
df1.drop(var_to_remove,axis=1,inplace=True)
df1
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10524\4230202639.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(var_to_remove,axis=1,inplace=True)
#          MONTH  DAY  SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  \
# 4971115     11    7                  702             -8.0       192
# 1471676      4    5                  957             45.0       214
# 318454       1   21                 1930            -13.0       431
# 564428       2    7                  820             -2.0       265
# 2375725      5   31                 1200             -5.0       762
# ...        ...  ...                  ...              ...       ...
# 501163       2    3                  715              0.0       528
# 5636536     12   20                  730             -5.0       391
# ...

# %%
data=pd.concat([df1,df_cat],axis=1)
data
# Out:
#          MONTH  DAY  SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  \
# 4971115     11    7                  702             -8.0       192
# 1471676      4    5                  957             45.0       214
# 318454       1   21                 1930            -13.0       431
# 564428       2    7                  820             -2.0       265
# 2375725      5   31                 1200             -5.0       762
# ...        ...  ...                  ...              ...       ...
# 501163       2    3                  715              0.0       528
# 5636536     12   20                  730             -5.0       391
# 3719447      8   19                 1325             58.0      1628
# 4927718     11    4                 1257             -3.0       255
# 2676797      6   18                 1025             -7.0       644
#
#          ARRIVAL_DELAY  AIRLINE_AS  AIRLINE_B6  AIRLINE_DL  AIRLINE_EV  ...  \
# ...

# %%
data.shape
# Out:
# (98143, 663)

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
X=data.drop("DEPARTURE_DELAY",axis=1)
Y=data.DEPARTURE_DELAY

# %%
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Using Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
reg_rf = RandomForestRegressor()
reg_rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = reg_rf.predict(X_test)

# %%
reg_rf.score(X_train,y_train)
# Out:
# 0.9896755962802213

# %%
reg_rf.score(X_test,y_test)
# Out:
# 0.9298366171275503

# %%
metrics.r2_score(y_test,y_pred)
# Out:
# 0.9298366171275503

# %%
print('MAE:', metrics.mean_absolute_error(y_test,y_pred))
print('MSE:', metrics.mean_squared_error(y_test,y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# MAE: 5.961163584492333
# MSE: 95.20150216516377
# RMSE: 9.757125712276325

# %%
pp=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
pp
# Out:
#          Actual  Predicted
# 4247020    -4.0      -1.29
# 2498869     0.0      -2.09
# 1091500     1.0       5.95
# 4959955    -2.0       6.75
# 935329     12.0      21.22
# ...         ...        ...
# 5340597    -2.0      -4.85
# 2525907    -2.0      -2.63
# 934237     -6.0      -1.94
# 3593232     2.0      -2.51
# 1270408   141.0     142.92
#
# [19629 rows x 2 columns]

# %%
### Using Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor(random_state=0)

# %%
GBR=gbr.fit(X_train,y_train)
pre=GBR.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test,pre))
print('MSE:', metrics.mean_squared_error(y_test,pre))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,pre)))
# Out:
# MAE: 5.959985623489245
# MSE: 91.86086619347734
# RMSE: 9.584407451349161

# %%
metrics.r2_score(y_test,pre)
# Out:
# 0.9322986614796684

# %%
gg=pd.DataFrame({'Actual':y_test,'Predicted':pre})
gg
# Out:
#          Actual   Predicted
# 4247020    -4.0   -1.041139
# 2498869     0.0   -1.101711
# 1091500     1.0    4.098353
# 4959955    -2.0    3.765807
# 935329     12.0   13.926358
# ...         ...         ...
# 5340597    -2.0   -4.228212
# 2525907    -2.0   -2.067548
# 934237     -6.0   -1.129164
# 3593232     2.0   -0.456503
# 1270408   141.0  141.543634
#
# [19629 rows x 2 columns]

# %%
def predict(MONTH, DAY,SCHEDULED_DEPARTURE,DISTANCE, ARRIVAL_DELAY,AIRLINE,ORIGIN_AIRPORT,DESTINATION_AIRPORT,DAY_OF_WEEK):
    AIRLINE_index = np.where(X.columns==AIRLINE)[0][0]
    ORIGIN_index = np.where(X.columns==ORIGIN_AIRPORT)[0][0]
    DESTINATION_index = np.where(X.columns==DESTINATION_AIRPORT)[0][0]
    DAY_OF_WEEK_index = np.where(X.columns==DAY_OF_WEEK)[0][0]
    x= np.zeros(len(X.columns))
    x[0] = MONTH
    x[1] = DAY
    x[2] = SCHEDULED_DEPARTURE
    x[3] = DISTANCE
    x[4] = ARRIVAL_DELAY
    if AIRLINE_index >=0:
        x[AIRLINE_index] = 1
    if ORIGIN_index >=0:
        x[ORIGIN_index] = 1
    if DESTINATION_index >=0:
        x[DESTINATION_index] = 1
    if  DAY_OF_WEEK_index >= 0:
        x[ DAY_OF_WEEK_index] = 1

    return gbr.predict([x])[0]

# %%
res= predict(5,6,1515,328,-8.0,'AIRLINE_OO','ORIGIN_AIRPORT_PHX','DESTINATION_AIRPORT_ABQ','DAY_OF_WEEK_TUESDAY')
res
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# -4.058653664139189

# %%
if(res<=-15):
    print("Flight is delayed")
else:
    print("Flight is not delayed")
# Out:
# Flight is not delayed
